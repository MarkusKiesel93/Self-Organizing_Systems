# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load Results

# %%
RESULTS_FILE = './results.csv'
NUMBER_OF_EXPERIMENTS = 27 * 228
PARAM_COLUMNS = ['fitness_function', 'use_constraint', 'constraint_handling_method', 'constraint',
                 'particle_speed_limit', 'population_size', 'personal_confidence', 'swarm_confidence',
                 'particle_inertia', 'constraint_r']
RESULT_COLUMNS_ALL = ['fitness', 'optimum', 'iterations', 'optimum_reached', 'iterations_to_opt']#
RESULT_COLUMNS = ['fitness', 'optimum', 'optimum_reached', 'iterations_to_opt']

# %%
df_all_iterations = pd.read_csv(RESULTS_FILE)
df_all_iterations.head()
# Out:
#    number  iteration  fitness_function  use_constraint  \
# 0   10001          1  Shubert function           False
# 1   10002          1  Shubert function           False
# 2   10003          1  Shubert function           False
# 3   10004          1  Shubert function           False
# 4   10005          1  Shubert function           False
#
#   constraint_handling_method constraint  particle_speed_limit  \
# 0                        NaN        NaN                    13
# 1                        NaN        NaN                    13
# 2                        NaN        NaN                    13
# 3                        NaN        NaN                    13
# 4                        NaN        NaN                    13
#
#    population_size  personal_confidence  swarm_confidence  particle_inertia  \
# 0                5                  0.5               1.5               0.1
# 1                5                  1.0               1.0               0.1
# 2                5                  1.5               0.5               0.1
# 3                5                  0.5               1.5               0.5
# 4                5                  1.0               1.0               0.5
#
#    constraint_r   fitness  optimum  iterations  optimum_reached  \
# 0         -0.15  0.749117      1.0         500            False
# 1         -0.15  0.641035      1.0         500            False
# 2         -0.15  0.698651      1.0         500            False
# 3         -0.15  0.749117      1.0         500            False
# 4         -0.15  0.749117      1.0         500            False
#
#    iterations_to_opt
# 0                  9
# 1                 33
# 2                  0
# 3                 15
# 4                 15

# %% [markdown]
# # Experiment Parameters

# %%
df_params = df_all_iterations[['number'] + PARAM_COLUMNS].drop_duplicates().set_index('number')
df_params.constraint_r.replace(-0.15, np.nan, inplace=True)  # default was used when no constraint used -> change to NAN
assert df_params.index.is_unique
assert df_params.shape == (NUMBER_OF_EXPERIMENTS, len(PARAM_COLUMNS))
df_params.head()
# Out:
#         fitness_function  use_constraint constraint_handling_method  \
# number
# 10001   Shubert function           False                        NaN
# 10002   Shubert function           False                        NaN
# 10003   Shubert function           False                        NaN
# 10004   Shubert function           False                        NaN
# 10005   Shubert function           False                        NaN
#
#        constraint  particle_speed_limit  population_size  personal_confidence  \
# number
# 10001         NaN                    13                5                  0.5
# 10002         NaN                    13                5                  1.0
# 10003         NaN                    13                5                  1.5
# 10004         NaN                    13                5                  0.5
# 10005         NaN                    13                5                  1.0
#
#         swarm_confidence  particle_inertia  constraint_r
# number
# 10001                1.5               0.1           NaN
# 10002                1.0               0.1           NaN
# 10003                0.5               0.1           NaN
# 10004                1.5               0.5           NaN
# 10005                1.0               0.5           NaN

# %%
# sanity check params
assert set(df_params.fitness_function.unique()) == set(['Shubert function', "Booth's function", 'Schwefel function'])#
assert set(df_params.use_constraint.unique()) == set([True, False])
assert set(df_params.constraint_handling_method.unique()) == set([np.nan, 'Penalty Method', 'Rejection Method'])
assert set(df_params.constraint.unique()) == set([np.nan, 'Constraint 3', 'Constraint 5', 'Constraint 10'])
# assert set(df_params.particle_speed_limit.unique()) == set([2, 10, 19])
assert df_params.particle_speed_limit.unique() == [13] # redo some experiments with variation
assert set(df_params.population_size.unique()) == set([5, 10, 35, 80])
assert set(df_params.personal_confidence.unique()) == set([0.5, 1.0, 1.5])
assert set(df_params.swarm_confidence.unique()) == set([0.5, 1.0, 1.5])
assert set(df_params.particle_inertia.unique()) == set([0.1, 0.5, 0.9])
assert set(df_params.constraint_r.dropna().unique()) == set([-1.0, -1.5, -2.0])
assert df_params[~df_params.use_constraint][['constraint_handling_method', 'constraint', 'constraint_r']].isna().all(axis=None)
assert df_params[df_params.use_constraint][['constraint_handling_method', 'constraint', 'constraint_r']].notna().all(axis=None)

# %%
# inspect values in Experiment setup
for column in PARAM_COLUMNS:
    print(f'{column}: {df_params[column].unique()}')
# Out:
# fitness_function: ['Shubert function' "Booth's function" 'Schwefel function']
# use_constraint: [False  True]
# constraint_handling_method: [nan 'Penalty Method' 'Rejection Method']
# constraint: [nan 'Constraint 3' 'Constraint 5' 'Constraint 10']
# particle_speed_limit: [13]
# population_size: [ 5 10 35 80]
# personal_confidence: [0.5 1.  1.5]
# swarm_confidence: [1.5 1.  0.5]
# particle_inertia: [0.1 0.5 0.9]
# constraint_r: [ nan -1.  -1.5 -2. ]

# %% [markdown]
# # Experiment Results

# %%
df_results = df_all_iterations[['number'] + RESULT_COLUMNS_ALL]
df_results = df_results.groupby('number').mean()
## sanity check results
assert df_results.shape == (NUMBER_OF_EXPERIMENTS, len(RESULT_COLUMNS_ALL))
assert df_results.fitness.min() >= 0.0
assert df_results.fitness.max() <= 1.0
assert df_results.optimum.min() > 0.0
assert df_results.optimum.max() <= 1.0
assert df_results.iterations.unique() == [500.0]
assert df_results.optimum_reached.min() >= 0.0
assert df_results.optimum_reached.max() <= 1.0
assert df_results.iterations_to_opt.min() >= 0
assert df_results.iterations_to_opt.max() <= 500
df_results.head()
# Out:
#          fitness  optimum  iterations  optimum_reached  iterations_to_opt
# number
# 10001   0.685586      1.0       500.0              0.0                8.5
# 10002   0.632124      1.0       500.0              0.0              144.0
# 10003   0.700413      1.0       500.0              0.0                5.0
# 10004   0.686165      1.0       500.0              0.0               14.0
# 10005   0.686165      1.0       500.0              0.0               21.5

# %%
df_results[RESULT_COLUMNS].describe()
# Out:
#            fitness      optimum  optimum_reached  iterations_to_opt
# count  6156.000000  6156.000000      6156.000000        6156.000000
# mean      0.896854     0.930320         0.550520          39.536712
# std       0.158699     0.152377         0.466556          65.502258
# min       0.471753     0.495829         0.000000           0.000000
# 25%       0.874587     0.924913         0.000000           8.000000
# 50%       0.984247     1.000000         0.500000          16.000000
# 75%       1.000000     1.000000         1.000000          38.500000
# max       1.000000     1.000000         1.000000         498.000000

# %% [markdown]
# # Combined Data by Experiment

# %%
df = df_params.join(df_results)
assert df.shape == (NUMBER_OF_EXPERIMENTS, len(PARAM_COLUMNS) + len(RESULT_COLUMNS_ALL))
df.head()
# Out:
#         fitness_function  use_constraint constraint_handling_method  \
# number
# 10001   Shubert function           False                        NaN
# 10002   Shubert function           False                        NaN
# 10003   Shubert function           False                        NaN
# 10004   Shubert function           False                        NaN
# 10005   Shubert function           False                        NaN
#
#        constraint  particle_speed_limit  population_size  personal_confidence  \
# number
# 10001         NaN                    13                5                  0.5
# 10002         NaN                    13                5                  1.0
# 10003         NaN                    13                5                  1.5
# 10004         NaN                    13                5                  0.5
# 10005         NaN                    13                5                  1.0
#
#         swarm_confidence  particle_inertia  constraint_r   fitness  optimum  \
# number
# 10001                1.5               0.1           NaN  0.685586      1.0
# 10002                1.0               0.1           NaN  0.632124      1.0
# 10003                0.5               0.1           NaN  0.700413      1.0
# 10004                1.5               0.5           NaN  0.686165      1.0
# 10005                1.0               0.5           NaN  0.686165      1.0
#
#         iterations  optimum_reached  iterations_to_opt
# number
# 10001        500.0              0.0                8.5
# 10002        500.0              0.0              144.0
# 10003        500.0              0.0                5.0
# 10004        500.0              0.0               14.0
# 10005        500.0              0.0               21.5

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Confidence

# %%
def show_evaluation(feature='particle_inertia', use_constraint=False, average_constraint_handling=False, average_constraints=False, round_to=2):
    features = ['fitness_function', feature]
    
    if use_constraint:
        if not average_constraint_handling:
            features.append('constraint_handling_method')
            
        if not average_constraints:
            features.append('constraint')
    
    return df[df.use_constraint].groupby(features)[RESULT_COLUMNS].mean().round(round_to).astype(str) + " +/- " + df[df.use_constraint].groupby(features)[RESULT_COLUMNS].std().round(round_to).astype(str)

# %%
show_evaluation(use_constraint=True, average_constraint_handling=True)
# Out:
#                                                         fitness       optimum  \
# fitness_function  particle_inertia constraint
# Booth's function  0.1              Constraint 10   0.9 +/- 0.05  0.92 +/- 0.0
#                                    Constraint 3    1.0 +/- 0.01   1.0 +/- 0.0
#                                    Constraint 5   0.99 +/- 0.01   1.0 +/- 0.0
#                   0.5              Constraint 10   0.9 +/- 0.05  0.92 +/- 0.0
#                                    Constraint 3     1.0 +/- 0.0   1.0 +/- 0.0
#                                    Constraint 5     1.0 +/- 0.0   1.0 +/- 0.0
#                   0.9              Constraint 10   0.9 +/- 0.05  0.92 +/- 0.0
#                                    Constraint 3     1.0 +/- 0.0   1.0 +/- 0.0
#                                    Constraint 5     1.0 +/- 0.0   1.0 +/- 0.0
# Schwefel function 0.1              Constraint 10   0.9 +/- 0.03  0.92 +/- 0.0
#                                    Constraint 3   0.97 +/- 0.06   1.0 +/- 0.0
#                                    Constraint 5   0.87 +/- 0.14   1.0 +/- 0.0
#                   0.5              Constraint 10  0.91 +/- 0.02  0.92 +/- 0.0
#                                    Constraint 3   0.98 +/- 0.05   1.0 +/- 0.0
#                                    Constraint 5    0.9 +/- 0.13   1.0 +/- 0.0
#                   0.9              Constraint 10  0.92 +/- 0.01  0.92 +/- 0.0
#                                    Constraint 3     1.0 +/- 0.0   1.0 +/- 0.0
#                                    Constraint 5   0.97 +/- 0.07   1.0 +/- 0.0
# Shubert function  0.1              Constraint 10  0.49 +/- 0.01   0.5 +/- 0.0
#                                    Constraint 3   0.96 +/- 0.08   1.0 +/- 0.0
#                                    Constraint 5   0.87 +/- 0.12   1.0 +/- 0.0
#                   0.5              Constraint 10    0.5 +/- 0.0   0.5 +/- 0.0
#                                    Constraint 3   0.97 +/- 0.07   1.0 +/- 0.0
#                                    Constraint 5    0.9 +/- 0.11   1.0 +/- 0.0
#                   0.9              Constraint 10    0.5 +/- 0.0   0.5 +/- 0.0
#                                    Constraint 3   0.97 +/- 0.06   1.0 +/- 0.0
#                                    Constraint 5    0.9 +/- 0.11   1.0 +/- 0.0
#
#                                                  optimum_reached  \
# fitness_function  particle_inertia constraint
# Booth's function  0.1              Constraint 10   0.41 +/- 0.47
#                                    Constraint 3    0.41 +/- 0.46
#                                    Constraint 5    0.17 +/- 0.38
#                   0.5              Constraint 10    0.5 +/- 0.46
#                                    Constraint 3    0.85 +/- 0.28
#                                    Constraint 5    0.69 +/- 0.41
#                   0.9              Constraint 10   0.58 +/- 0.45
#                                    Constraint 3      1.0 +/- 0.0
#                                    Constraint 5      1.0 +/- 0.0
# Schwefel function 0.1              Constraint 10   0.05 +/- 0.21
#                                    Constraint 3    0.19 +/- 0.39
#                                    Constraint 5      0.1 +/- 0.3
#                   0.5              Constraint 10   0.35 +/- 0.47
#                                    Constraint 3    0.55 +/- 0.47
#                                    Constraint 5    0.31 +/- 0.46
#                   0.9              Constraint 10   0.83 +/- 0.32
#                                    Constraint 3    0.55 +/- 0.49
#                                    Constraint 5     0.52 +/- 0.5
# Shubert function  0.1              Constraint 10   0.47 +/- 0.46
#                                    Constraint 3    0.63 +/- 0.43
#                                    Constraint 5     0.3 +/- 0.44
#                   0.5              Constraint 10   0.65 +/- 0.39
#                                    Constraint 3    0.82 +/- 0.32
#                                    Constraint 5    0.56 +/- 0.44
#                   0.9              Constraint 10   0.68 +/- 0.38
#                                    Constraint 3    0.92 +/- 0.19
#                                    Constraint 5    0.65 +/- 0.38
#
#                                                  iterations_to_opt
# fitness_function  particle_inertia constraint
# Booth's function  0.1              Constraint 10  61.43 +/- 101.35
#                                    Constraint 3    16.26 +/- 47.94
#                                    Constraint 5    16.88 +/- 19.53
#                   0.5              Constraint 10   34.01 +/- 55.65
#                                    Constraint 3      9.32 +/- 5.35
#                                    Constraint 5      20.9 +/- 34.3
#                   0.9              Constraint 10   55.24 +/- 83.12
#                                    Constraint 3    22.78 +/- 15.04
#                                    Constraint 5     23.88 +/- 16.4
# Schwefel function 0.1              Constraint 10   56.26 +/- 88.36
#                                    Constraint 3    38.35 +/- 69.32
#                                    Constraint 5   88.96 +/- 117.78
#                   0.5              Constraint 10   42.35 +/- 64.76
#                                    Constraint 3    24.43 +/- 25.21
#                                    Constraint 5    67.39 +/- 65.13
#                   0.9              Constraint 10    83.94 +/- 92.8
#                                    Constraint 3     25.8 +/- 19.53
#                                    Constraint 5    52.59 +/- 44.54
# Shubert function  0.1              Constraint 10   20.75 +/- 43.84
#                                    Constraint 3    20.49 +/- 36.41
#                                    Constraint 5   74.02 +/- 101.16
#                   0.5              Constraint 10   30.12 +/- 58.31
#                                    Constraint 3    20.86 +/- 47.63
#                                    Constraint 5    46.61 +/- 75.96
#                   0.9              Constraint 10   28.24 +/- 40.52
#                                    Constraint 3    28.59 +/- 33.17
#                                    Constraint 5    42.11 +/- 46.16

# %% [markdown]
# # Correlation

# %%
df.drop(columns=["use_constraint", "iterations"]).corr()
# Out:
# C:\Users\karst\AppData\Local\Temp\ipykernel_10864\2416084564.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.drop(columns=["use_constraint", "iterations"]).corr()
#                       particle_speed_limit  population_size  \
# particle_speed_limit                   NaN              NaN
# population_size                        NaN     1.000000e+00
# personal_confidence                    NaN     2.245036e-15
# swarm_confidence                       NaN    -6.410103e-16
# particle_inertia                       NaN    -9.345388e-18
# constraint_r                           NaN     4.087378e-15
# fitness                                NaN     1.529724e-01
# optimum                                NaN    -3.012438e-15
# optimum_reached                        NaN     3.820622e-01
# iterations_to_opt                      NaN    -1.861066e-01
#
#                       personal_confidence  swarm_confidence  particle_inertia  \
# particle_speed_limit                  NaN               NaN               NaN
# population_size              2.245036e-15     -6.410103e-16     -9.345388e-18
# personal_confidence          1.000000e+00     -1.000000e+00      2.434700e-18
# swarm_confidence            -1.000000e+00      1.000000e+00      1.352611e-18
# particle_inertia             2.434700e-18      1.352611e-18      1.000000e+00
# constraint_r                -1.553398e-17      1.050828e-17     -6.282126e-18
# fitness                     -6.593725e-03      6.593725e-03      6.128127e-02
# optimum                      1.699272e-16      2.464639e-16      9.439959e-18
# optimum_reached             -7.463049e-02      7.463049e-02      3.863727e-01
# iterations_to_opt            1.296556e-01     -1.296556e-01     -2.710574e-02
#
#                       constraint_r   fitness       optimum  optimum_reached  \
# particle_speed_limit           NaN       NaN           NaN              NaN
# population_size       4.087378e-15  0.152972 -3.012438e-15         0.382062
# personal_confidence  -1.553398e-17 -0.006594  1.699272e-16        -0.074630
# swarm_confidence      1.050828e-17  0.006594  2.464639e-16         0.074630
# particle_inertia     -6.282126e-18  0.061281  9.439959e-18         0.386373
# constraint_r          1.000000e+00  0.018253  8.667159e-17         0.008099
# fitness               1.825301e-02  1.000000  8.770338e-01         0.196999
# optimum               8.667159e-17  0.877034  1.000000e+00        -0.013000
# optimum_reached       8.098888e-03  0.196999 -1.299964e-02         1.000000
# iterations_to_opt    -5.617346e-02 -0.016953  4.381324e-02        -0.210113
#
#                       iterations_to_opt
# particle_speed_limit                NaN
# population_size               -0.186107
# personal_confidence            0.129656
# swarm_confidence              -0.129656
# particle_inertia              -0.027106
# constraint_r                  -0.056173
# fitness                       -0.016953
# optimum                        0.043813
# optimum_reached               -0.210113
# iterations_to_opt              1.000000
