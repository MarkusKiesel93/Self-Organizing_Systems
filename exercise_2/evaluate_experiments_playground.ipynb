# %%
import pandas as pd
import numpy as np
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
EXPERIMENT_SETUP_FILE = './experiment_setup.csv'
df = pd.read_csv(EXPERIMENT_SETUP_FILE, index_col='number').dropna(axis=1)  # ignore last unused column

# %%
df.head()
# Out:
#          fitness_function  use_constraint constraint_handling_method  \
# number
# 0        Shubert function            True             Penalty Method
# 1        Booth's function            True             Penalty Method
# 2       Schwefel function            True             Penalty Method
# 3        Shubert function            True             Penalty Method
# 4        Booth's function            True             Penalty Method
#
#           constraint  particle_speed_limit  population_size  \
# number
# 0       Constraint 3                    13               13
# 1       Constraint 3                    13               13
# 2       Constraint 3                    13               13
# 3       Constraint 3                     2               13
# 4       Constraint 3                     2               13
#
#         personal_confidence  swarm_confidence  particle_inertia  constraint_r
# number
# 0                       0.8               1.6               0.3         -0.15
# 1                       0.8               1.6               0.3         -0.15
# 2                       0.8               1.6               0.3         -0.15
# 3                       0.8               1.6               0.3         -0.15
# 4                       0.8               1.6               0.3         -0.15

# %%
df.describe()
# Out:
#        particle_speed_limit  population_size  personal_confidence  \
# count            180.000000            180.0           180.000000
# mean              12.300000             13.0             0.770000
# std                4.184168              0.0             0.237515
# min                2.000000             13.0             0.100000
# 25%               13.000000             13.0             0.800000
# 50%               13.000000             13.0             0.800000
# 75%               13.000000             13.0             0.800000
# max               20.000000             13.0             1.000000
#
#        swarm_confidence  particle_inertia  constraint_r
# count        180.000000        180.000000  1.800000e+02
# mean           1.250000          0.350000 -1.500000e-01
# std            0.489727          0.225349  2.783300e-17
# min            0.100000          0.100000 -1.500000e-01
# 25%            1.000000          0.300000 -1.500000e-01
# 50%            1.600000          0.300000 -1.500000e-01
# 75%            1.600000          0.300000 -1.500000e-01
# max            1.600000          1.000000 -1.500000e-01

# %%
# values in Experiment setup
for column in df.columns:
    print(f'{column}: {df[column].unique()}')
# Out:
# fitness_function: ['Shubert function' "Booth's function" 'Schwefel function']
# use_constraint: [ True]
# constraint_handling_method: ['Penalty Method' 'Rejection Method']
# constraint: ['Constraint 3' 'Constraint 5' 'Constraint 10']
# particle_speed_limit: [13  2 10 20]
# population_size: [13]
# personal_confidence: [0.8 0.1 1. ]
# swarm_confidence: [1.6 1.  0.8 0.1]
# particle_inertia: [0.3 0.1 1. ]
# constraint_r: [-0.15]

# %% [markdown]
# # Results

# %%
results_df = pd.read_csv("results28-12_14-45-54.csv", na_values="-")

# %%
results_df
# Out:
#     number  iteration  fitness_function  use_constraint  \
# 0    10001          1  Shubert function           False
# 1    10002          1  Shubert function           False
# 2    10003          1  Shubert function           False
# 3    10004          1  Shubert function           False
# 4    10005          1  Shubert function           False
# 5    10006          1  Shubert function           False
# 6    10007          1  Shubert function           False
# 7    10008          1  Shubert function           False
# 8    10009          1  Shubert function           False
# 9    10010          1  Shubert function           False
# 10   10011          1  Shubert function           False
# 11   10012          1  Shubert function           False
# 12   10013          1  Shubert function           False
# 13   10014          1  Shubert function           False
# 14   10015          1  Shubert function           False
# 15   10016          1  Shubert function           False
# 16   10017          1  Shubert function           False
# 17   10018          1  Shubert function           False
# 18   10019          1  Shubert function           False
# 19   10020          1  Shubert function           False
# 20   10021          1  Shubert function           False
# 21   10022          1  Shubert function           False
# 22   10023          1  Shubert function           False
# 23   10024          1  Shubert function           False
# 24   10025          1  Shubert function           False
# 25   10026          1  Shubert function           False
# 26   10027          1  Shubert function           False
# 27   10028          1  Shubert function           False
# 28   10029          1  Shubert function           False
# 29   10030          1  Shubert function           False
# 30   10031          1  Shubert function           False
# 31   10032          1  Shubert function           False
# 32   10033          1  Shubert function           False
# 33   10034          1  Shubert function           False
# 34   10035          1  Shubert function           False
# 35   10036          1  Shubert function           False
# 36   10037          1  Shubert function           False
# 37   10038          1  Shubert function           False
# 38   10039          1  Shubert function           False
# 39   10040          1  Shubert function           False
# 40   10041          1  Shubert function           False
#
#     constraint_handling_method  constraint  particle_speed_limit  \
# 0                          NaN         NaN                    13
# 1                          NaN         NaN                    13
# 2                          NaN         NaN                    13
# 3                          NaN         NaN                    13
# 4                          NaN         NaN                    13
# 5                          NaN         NaN                    13
# 6                          NaN         NaN                    13
# 7                          NaN         NaN                    13
# 8                          NaN         NaN                    13
# 9                          NaN         NaN                    13
# 10                         NaN         NaN                    13
# 11                         NaN         NaN                    13
# 12                         NaN         NaN                    13
# 13                         NaN         NaN                    13
# 14                         NaN         NaN                    13
# 15                         NaN         NaN                    13
# 16                         NaN         NaN                    13
# 17                         NaN         NaN                    13
# 18                         NaN         NaN                    13
# 19                         NaN         NaN                    13
# 20                         NaN         NaN                    13
# 21                         NaN         NaN                    13
# 22                         NaN         NaN                    13
# 23                         NaN         NaN                    13
# 24                         NaN         NaN                    13
# 25                         NaN         NaN                    13
# 26                         NaN         NaN                    13
# 27                         NaN         NaN                    13
# 28                         NaN         NaN                    13
# 29                         NaN         NaN                    13
# 30                         NaN         NaN                    13
# 31                         NaN         NaN                    13
# 32                         NaN         NaN                    13
# 33                         NaN         NaN                    13
# 34                         NaN         NaN                    13
# 35                         NaN         NaN                    13
# 36                         NaN         NaN                    13
# 37                         NaN         NaN                    13
# 38                         NaN         NaN                    13
# 39                         NaN         NaN                    13
# 40                         NaN         NaN                    13
#
#     population_size  personal_confidence  swarm_confidence  particle_inertia  \
# 0                25                  0.5               0.5              0.10
# 1                25                  0.5               0.5              0.10
# 2                25                  0.5               0.5              0.10
# 3                25                  0.5               1.0              0.10
# 4                25                  0.5               1.0              0.10
# 5                25                  0.5               1.0              0.10
# 6                25                  0.5               1.5              0.10
# 7                25                  0.5               1.5              0.10
# 8                25                  0.5               1.5              0.10
# 9                25                  1.0               0.5              0.10
# 10               25                  1.0               0.5              0.10
# 11               25                  1.0               0.5              0.10
# 12               25                  1.0               1.0              0.10
# 13               25                  1.0               1.0              0.10
# 14               25                  1.0               1.0              0.10
# 15               25                  1.0               1.5              0.10
# 16               25                  1.0               1.5              0.10
# 17               25                  1.0               1.5              0.10
# 18               25                  1.5               0.5              0.10
# 19               25                  1.5               0.5              0.10
# 20               25                  1.5               0.5              0.10
# 21               25                  1.5               1.0              0.10
# 22               25                  1.5               1.0              0.10
# 23               25                  1.5               1.0              0.10
# 24               25                  1.5               1.5              0.10
# 25               25                  1.5               1.5              0.10
# 26               25                  1.5               1.5              0.10
# 27               25                  0.5               0.5              0.25
# 28               25                  0.5               0.5              0.25
# 29               25                  0.5               0.5              0.25
# 30               25                  0.5               1.0              0.25
# 31               25                  0.5               1.0              0.25
# 32               25                  0.5               1.0              0.25
# 33               25                  0.5               1.5              0.25
# 34               25                  0.5               1.5              0.25
# 35               25                  0.5               1.5              0.25
# 36               25                  1.0               0.5              0.25
# 37               25                  1.0               0.5              0.25
# 38               25                  1.0               0.5              0.25
# 39               25                  1.0               1.0              0.25
# 40               25                  1.0               1.0              0.25
#
#     constraint_r   fitness  optimum  iterations  optimum_reached  \
# 0          -0.25  1.000000      1.0         500             True
# 1          -0.50  1.000000      1.0         500             True
# 2          -0.75  1.000000      1.0         500             True
# 3          -0.25  1.000000      1.0         500             True
# 4          -0.50  1.000000      1.0         500             True
# 5          -0.75  1.000000      1.0         500             True
# 6          -0.25  1.000000      1.0         500             True
# 7          -0.50  1.000000      1.0         500             True
# 8          -0.75  1.000000      1.0         500             True
# 9          -0.25  1.000000      1.0         500             True
# 10         -0.50  1.000000      1.0         500             True
# 11         -0.75  1.000000      1.0         500             True
# 12         -0.25  1.000000      1.0         500             True
# 13         -0.50  1.000000      1.0         500             True
# 14         -0.75  1.000000      1.0         500             True
# 15         -0.25  1.000000      1.0         500             True
# 16         -0.50  1.000000      1.0         500             True
# 17         -0.75  1.000000      1.0         500             True
# 18         -0.25  1.000000      1.0         500             True
# 19         -0.50  1.000000      1.0         500             True
# 20         -0.75  1.000000      1.0         500             True
# 21         -0.25  1.000000      1.0         500             True
# 22         -0.50  1.000000      1.0         500             True
# 23         -0.75  1.000000      1.0         500             True
# 24         -0.25  1.000000      1.0         500             True
# 25         -0.50  1.000000      1.0         500             True
# 26         -0.75  1.000000      1.0         500             True
# 27         -0.25  1.000000      1.0         500             True
# 28         -0.50  1.000000      1.0         500             True
# 29         -0.75  1.000000      1.0         500             True
# 30         -0.25  1.000000      1.0         500             True
# 31         -0.50  1.000000      1.0         500             True
# 32         -0.75  1.000000      1.0         500             True
# 33         -0.25  1.000000      1.0         500             True
# 34         -0.50  1.000000      1.0         500             True
# 35         -0.75  1.000000      1.0         500             True
# 36         -0.25  0.997824      1.0         500            False
# 37         -0.50  0.997824      1.0         500            False
# 38         -0.75  0.997824      1.0         500            False
# 39         -0.25  1.000000      1.0         500             True
# 40         -0.50  1.000000      1.0         500             True
#
#     iterations_to_opt
# 0                  12
# 1                  12
# 2                  12
# 3                   8
# 4                   8
# 5                   8
# 6                   4
# 7                   4
# 8                   4
# 9                  12
# 10                 12
# 11                 12
# 12                  9
# 13                  9
# 14                  9
# 15                  7
# 16                  7
# 17                  7
# 18                 24
# 19                 24
# 20                 24
# 21                 15
# 22                 15
# 23                 15
# 24                  9
# 25                  9
# 26                  9
# 27                  7
# 28                  7
# 29                  7
# 30                  4
# 31                  4
# 32                  4
# 33                  7
# 34                  7
# 35                  7
# 36                410
# 37                410
# 38                410
# 39                 10
# 40                 10

# %%
xx  = []
yy_loc, yy_opt = [], []
std_loc, std_opt = [], []
for value, data  in results_df.groupby("personal_confidence"):
    data_opt = data[data["optimum_reached"] == True]
    data_loc = data[data["optimum_reached"] == False]
    print(f"{round(len(data_opt) / (len(data_opt) + len(data_loc)) * 100, 2)}% found the optimal value of {len(data_opt) + len(data_loc)} runs.")
    display(value)
    print(f'{data_opt["iterations_to_opt"].mean()} +/- {data_opt["iterations_to_opt"].std()}')
    xx.append(value)
    yy_opt.append(data_opt["iterations_to_opt"].mean())
    yy_loc.append(data_loc["iterations_to_opt"].mean())
    std_opt.append(data_opt["iterations_to_opt"].std())
    std_loc.append(data_loc["iterations_to_opt"].std())
# Out:
# 100.0% found the optimal value of 18 runs.
# 0.5
# 7.0 +/- 2.7865221840769436
# 78.57% found the optimal value of 14 runs.
# 1.0
# 9.454545454545455 +/- 1.9679246105293957
# 100.0% found the optimal value of 9 runs.
# 1.5
# 16.0 +/- 6.5383484153110105

# %%
fig, axes = plt.subplots(1,2)

axes[0].errorbar(xx, yy_opt, std_opt)
axes[0].set_title("Global Optimum")
axes[0].set_xlabel("Personal Confidence")
axes[0].set_ylabel("Average number of iterations")

axes[1].errorbar(xx, yy_loc, std_loc)
axes[1].set_title("Local Optimum")
axes[1].set_xlabel("Personal Confidence")
axes[1].set_ylabel("Average number of iterations")

fig.tight_layout()

# %% [markdown]
# # Correlations

# %%
results_df.drop(columns=["number", "iteration"]).corr()
# Out:
# C:\Users\karst\AppData\Local\Temp\ipykernel_10468\2338905613.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   results_df.drop(columns=["number", "iteration"]).corr()
#                             use_constraint  constraint_handling_method  \
# use_constraint                         NaN                         NaN
# constraint_handling_method             NaN                         NaN
# constraint                             NaN                         NaN
# particle_speed_limit                   NaN                         NaN
# population_size                        NaN                         NaN
# personal_confidence                    NaN                         NaN
# swarm_confidence                       NaN                         NaN
# particle_inertia                       NaN                         NaN
# constraint_r                           NaN                         NaN
# fitness                                NaN                         NaN
# optimum                                NaN                         NaN
# iterations                             NaN                         NaN
# optimum_reached                        NaN                         NaN
# iterations_to_opt                      NaN                         NaN
#
#                             constraint  particle_speed_limit  population_size  \
# use_constraint                     NaN                   NaN              NaN
# constraint_handling_method         NaN                   NaN              NaN
# constraint                         NaN                   NaN              NaN
# particle_speed_limit               NaN                   NaN              NaN
# population_size                    NaN                   NaN              NaN
# personal_confidence                NaN                   NaN              NaN
# swarm_confidence                   NaN                   NaN              NaN
# particle_inertia                   NaN                   NaN              NaN
# constraint_r                       NaN                   NaN              NaN
# fitness                            NaN                   NaN              NaN
# optimum                            NaN                   NaN              NaN
# iterations                         NaN                   NaN              NaN
# optimum_reached                    NaN                   NaN              NaN
# iterations_to_opt                  NaN                   NaN              NaN
#
#                             personal_confidence  swarm_confidence  \
# use_constraint                              NaN               NaN
# constraint_handling_method                  NaN               NaN
# constraint                                  NaN               NaN
# particle_speed_limit                        NaN               NaN
# population_size                             NaN               NaN
# personal_confidence                    1.000000         -0.025438
# swarm_confidence                      -0.025438          1.000000
# particle_inertia                      -0.390199         -0.125730
# constraint_r                           0.008449          0.002722
# fitness                               -0.078947          0.322219
# optimum                                     NaN               NaN
# iterations                                  NaN               NaN
# optimum_reached                       -0.078947          0.322219
# iterations_to_opt                      0.110753         -0.346157
#
#                             particle_inertia  constraint_r   fitness  optimum  \
# use_constraint                           NaN           NaN       NaN      NaN
# constraint_handling_method               NaN           NaN       NaN      NaN
# constraint                               NaN           NaN       NaN      NaN
# particle_speed_limit                     NaN           NaN       NaN      NaN
# population_size                          NaN           NaN       NaN      NaN
# personal_confidence                -0.390199      0.008449 -0.078947      NaN
# swarm_confidence                   -0.125730      0.002722  0.322219      NaN
# particle_inertia                    1.000000      0.041758 -0.390199      NaN
# constraint_r                        0.041758      1.000000  0.008449      NaN
# fitness                            -0.390199      0.008449  1.000000      NaN
# optimum                                  NaN           NaN       NaN      NaN
# iterations                               NaN           NaN       NaN      NaN
# optimum_reached                    -0.390199      0.008449  1.000000      NaN
# iterations_to_opt                   0.372869     -0.008394 -0.998878      NaN
#
#                             iterations  optimum_reached  iterations_to_opt
# use_constraint                     NaN              NaN                NaN
# constraint_handling_method         NaN              NaN                NaN
# constraint                         NaN              NaN                NaN
# particle_speed_limit               NaN              NaN                NaN
# population_size                    NaN              NaN                NaN
# personal_confidence                NaN        -0.078947           0.110753
# swarm_confidence                   NaN         0.322219          -0.346157
# particle_inertia                   NaN        -0.390199           0.372869
# constraint_r                       NaN         0.008449          -0.008394
# fitness                            NaN         1.000000          -0.998878
# optimum                            NaN              NaN                NaN
# iterations                         NaN              NaN                NaN
# optimum_reached                    NaN         1.000000          -0.998878
# iterations_to_opt                  NaN        -0.998878           1.000000
